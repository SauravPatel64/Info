# %%
class Book:
    def __init__(self,BookNo,BookName,BookWritter):
        self.__BookNo = BookNo
        self.__BookName = BookName
        self.__BookWritter = BookWritter
        
    @property
    def BookNo(self):
        return self.__BookNo
    @property
    def BookName(self):
        return self.__BookNo
    @property
    def BookWritter(self):
        return self.__BookNo
    
    @BookName.setter
    def BookName(self,name):
        self.__BookName = name
        
    @BookWritter.setter
    def BookWritter(self,writter):
        self.__BookName = writter
        
    @BookName.deleter
    def BookName(self):
        del self.__BookName
        
    @BookWritter.deleter
    def BookName(self):
        del self.__BookWritter
        
b1 = Book(101,"Jakash","Saurav")
print("Book No:",b1.BookNo)
# Out:
# Book No: 101
